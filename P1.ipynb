# %% [markdown]
# # **Finding Lane Lines on the Road**
# ***
# In this project, you will use the tools you learned about in the lesson to identify lane lines on the road.  You can develop your pipeline on a series of individual images, and later apply the result to a video stream (really just a series of images). Check out the video clip "raw-lines-example.mp4" (also contained in this repository) to see what the output should look like after using the helper functions below.
#
# Once you have a result that looks roughly like "raw-lines-example.mp4", you'll need to get creative and try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines.  You can see an example of the result you're going for in the video "P1_example.mp4".  Ultimately, you would like to draw just one line for the left side of the lane, and one for the right.
#
# ---
# Let's have a look at our first image called 'test_images/solidWhiteRight.jpg'.  Run the 2 cells below (hit Shift-Enter or the "play" button above) to display the image.
#
# **Note** If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".
#
# ---

# %% [markdown]
# **The tools you have are color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.  You  are also free to explore and try other techniques that were not presented in the lesson.  Your goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).  Once you have a working pipeline, try it out on the video stream below.**
#
# ---
#
# <figure>
#  <img src="line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %%
import sys
print(sys.version)
# Out:
# 3.5.2 |Anaconda 4.2.0 (x86_64)| (default, Jul  2 2016, 17:52:12)
# [GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)]

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %%
cv2.__version__
# Out:
# '3.1.0'

# %%
#reading in an image
image = mpimg.imread('test_images/solidWhiteRight.jpg')
#printing out some stats and plotting
print('This image is:', type(image), 'with dimesions:', image.shape)
plt.imshow(image)  #call as plt.imshow(gray, cmap='gray') to show a grayscaled image
# Out:
# This image is: <class 'numpy.ndarray'> with dimesions: (540, 960, 3)

# %% [markdown]
# **Some OpenCV functions (beyond those introduced in the lesson) that might be useful for this project are:**
#
# `cv2.inRange()` for color selection
# `cv2.fillPoly()` for regions selection
# `cv2.line()` to draw lines on an image given endpoints
# `cv2.addWeighted()` to coadd / overlay two images
# `cv2.cvtColor()` to grayscale or change color
# `cv2.imwrite()` to output images to file
# `cv2.bitwise_and()` to apply a mask to an image
#
# **Check out the OpenCV documentation to learn about these and discover even more awesome functionality!**

# %% [markdown]
# # Helper functions

# %% [markdown]
# Below are some helper functions to help get you started. They should look familiar from the lesson!

# %%
import math

def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image


def draw_lines(img, lines, color=[255, 0, 0], thickness=2):
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
    for line in lines:
        for x1,y1,x2,y2 in line:
            cv2.line(img, (x1, y1), (x2, y2), color, thickness)

# %% [markdown]
# **Modified function hough_lines() to returns both:**
# - line image (rgb) and
# - array of line segment end points
#
# **Also added error checking for when no lines are found. It will just returns blank image without any lines.**

# %%
def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    line_img = np.zeros((*img.shape, 3), dtype=np.uint8)
    if lines is None:
        return line_img, lines
    draw_lines(line_img, lines)
    return line_img, lines

# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.8, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

# %% [markdown]
# ## Test on Images
#
# Now you should build your pipeline to work on the images in the directory "test_images"
# **You should make sure your pipeline works well on these images before you try the videos.**

# %%
import os
os.listdir("test_images/")
# Out:
# ['.DS_Store',
#  'output',
#  'solidWhiteCurve.jpg',
#  'solidWhiteRight.jpg',
#  'solidYellowCurve.jpg',
#  'solidYellowCurve2.jpg',
#  'solidYellowLeft.jpg',
#  'whiteCarLaneSwitch.jpg']

# %% [markdown]
# run your solution on all test_images and make copies into the test_images directory).

# %% [markdown]
# ## My Solution...

# %% [markdown]
# Build a function that takes Hough transform output (line segment endpoints) and returns a linear regression model of a best-fit straight line, using Ordinary Least Square (OLS) method. The coefficents could be extracted from the model via:
# - `model.coef_` = slope (m)
# - `model.intercept_` = y-intercept (b)

# %%
import sklearn.linear_model as skm

# function that inputs Hough lines, and returns slope & intercept, using linear regression
def find_linear_model(lines):
    x = []
    y = []
    for line in lines:
        [x1, y1, x2, y2] = line[0]
        x.append(x1)
        x.append(x2)
        y.append(y1)
        y.append(y2)
    X = np.array([x]).transpose()
    Y = np.array([y]).transpose()
    model = skm.LinearRegression(fit_intercept=True).fit(X,Y)
    return model

# %%
def find_lane_lines(image_in, plot_img=False, mode='normal'):

    # --- Turn it gray ---
    image_gray = grayscale(image_in)
    
    # --- add Gaussian blurring ---
    blur_kernel_size = 5
    image_gauss = gaussian_blur(image_gray, blur_kernel_size)

    # --- add Canny edge detection ---
    high_threshold = 150
    low_threshold = 50
    image_canny = canny(image_gauss, low_threshold, high_threshold)
    if (plot_img):
        print('Canny edges')
        plt.imshow(image_canny, cmap='gray')
        plt.show()

    # --- mask out area of interest ---
    [depth, width] = image_canny.shape
    bottom = 0 # (+) up
    h_bias = -40 # (+) up
    horizon_half_width = 25
    left_vert = np.array([[(0,depth-bottom),
                           (width/2-horizon_half_width, depth/2-h_bias),
                           (width/2+horizon_half_width, depth/2-h_bias),
                           (width/2+horizon_half_width, depth-bottom),
                           (0,depth-bottom)]], dtype=np.int32)
    right_vert =np.array([[(width, depth-bottom),
                           (width/2-horizon_half_width, depth-bottom),
                           (width/2-horizon_half_width, depth/2-h_bias),
                           (width/2+horizon_half_width, depth/2-h_bias),
                           (width, depth-bottom)]], dtype=np.int32)
    image_masked_left = region_of_interest(image_canny, left_vert)
    image_masked_right= region_of_interest(image_canny, right_vert)

    # --- Hough transform ---
    rho = 5 # distance resolution in pixels of the Hough grid
    theta = np.pi/180*0.1 # angular resolution in radians of the Hough grid
    threshold = 200     # minimum number of votes (intersections in Hough grid cell)
    min_line_length = 100 #minimum number of pixels making up a line
    max_line_gap = 50    # maximum gap in pixels between connectable line segments

    [image_hough_left, lines_left] = hough_lines(image_masked_left, rho, theta,
                                                 threshold, min_line_length, max_line_gap)
    [image_hough_right, lines_right] = hough_lines(image_masked_right, rho, theta,
                                                   threshold, min_line_length, max_line_gap)
    # --- diagnostic plotting ---
    if (plot_img):
        print('Hough left lane lines')
        x = [v[0] for v in left_vert[0]]
        y = [v[1] for v in left_vert[0]]
        plt.plot(x, y, '--b') #cropping area (left laneline zone)
        plt.imshow( weighted_img(image_hough_left,
                                    cv2.cvtColor(image_masked_left, cv2.COLOR_GRAY2BGR)))
        plt.show()

        print('Hough right lane lines')
        x = [v[0] for v in right_vert[0]]
        y = [v[1] for v in right_vert[0]]
        plt.plot(x, y, '--b') #plot cropping area (right laneline zone)
        plt.imshow( weighted_img(image_hough_right,
                                    cv2.cvtColor(image_masked_right, cv2.COLOR_GRAY2BGR)))
        plt.show()

    # --- draw best guess of lane lines ---

    line_image = np.copy(image_in)*0 # creating a blank image to draw lines on

    if (lines_left is not None):
        # extract lane line from linear regression model & construct line
        model_l = find_linear_model(lines_left)
        x_left = np.array([[0, width/2]]).transpose()
        y_left = model_l.predict(x_left)
        left_line = np.array(np.concatenate((x_left, y_left),1).flatten(),
                             ndmin=3, dtype=np.int32)
        # add lane line to image
        draw_lines(line_image, left_line, thickness=10)
        
    if (lines_right is not None):
        # extract lane line from linear regression model & construct line
        model_r = find_linear_model(lines_right)
        x_right= np.array([[width/2, width]]).transpose()
        y_right = model_r.predict(x_right)
        right_line = np.array(np.concatenate((x_right, y_right),1).flatten(),
                              ndmin=3, dtype=np.int32)
        # add lane line to image
        draw_lines(line_image, right_line, thickness=10)

    # --- output mode ---
    if (mode=='Canny'):
        image_canny_bgr = np.zeros((*image_canny.shape, 3), dtype=np.uint8)
        image_canny_bgr[:,:,0] = image_canny # make Canny edges RED
        final_image = weighted_img(image_canny_bgr, image_in)
    elif (mode=='Hough'):
        image_hough = weighted_img(image_hough_left, image_hough_right, α=1.0)
        final_image = weighted_img(image_hough, image_in)
    elif (mode=='normal'):
        final_image = weighted_img(line_image, image_in)
    else:
        final_image = weighted_img(line_image, image_in)

    # --- more diagnostic plotting ---
    if (plot_img):
        print('Linear Regression lane lines over Canny')
        plt.imshow(weighted_img(line_image, cv2.cvtColor(image_canny, cv2.COLOR_GRAY2BGR)))
        plt.show()

        print('Linear Regression lane lines over original')
        plt.imshow(final_image)
        plt.show()
    
    return final_image

# %%
# %time
output_img = find_lane_lines(image, mode='Normal')
plt.imshow(output_img)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs

# %%
output_img = find_lane_lines(image, plot_img=True)
# Out:
# Canny edges
# Hough left lane lines
# Hough right lane lines
# Linear Regression lane lines over Canny
# Linear Regression lane lines over original

# %%
path = 'test_images'
files = os.listdir(path)
files = [file for file in files if file.endswith('.jpg')] # only grab '.jpg' files
files
# Out:
# ['solidWhiteCurve.jpg',
#  'solidWhiteRight.jpg',
#  'solidYellowCurve.jpg',
#  'solidYellowCurve2.jpg',
#  'solidYellowLeft.jpg',
#  'whiteCarLaneSwitch.jpg']

# %%
for file in files:
    image = mpimg.imread(os.path.join(path,file))
    print('----',str(file),'----')
    output_img = find_lane_lines(image, plot_img=False) # turn flag ON to see intermediate images
    mpimg.imsave(os.path.join(path,'output',file),output_img)
# Out:
# ---- solidWhiteCurve.jpg ----
# ---- solidWhiteRight.jpg ----
# ---- solidYellowCurve.jpg ----
# ---- solidYellowCurve2.jpg ----
# ---- solidYellowLeft.jpg ----
# ---- whiteCarLaneSwitch.jpg ----

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
def process_image(image):
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image with lines are drawn on lanes)
    result = find_lane_lines(image,mode='Normal')
    return result

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
white_output = 'white.mp4'
clip1 = VideoFileClip("solidWhiteRight.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# [MoviePy] >>>> Building video white.mp4
# [MoviePy] Writing video white.mp4
# 100%|█████████▉| 221/222 [00:08<00:00, 25.12it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: white.mp4
#
# CPU times: user 8.36 s, sys: 1.27 s, total: 9.64 s
# Wall time: 9.23 s

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))

# %% [markdown]
# **At this point, if you were successful you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform.  Modify your draw_lines function accordingly and try re-running your pipeline.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'yellow.mp4'
clip2 = VideoFileClip('solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False)
# Out:
# [MoviePy] >>>> Building video yellow.mp4
# [MoviePy] Writing video yellow.mp4
# 100%|█████████▉| 681/682 [00:28<00:00, 23.89it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: yellow.mp4
#
# CPU times: user 26.8 s, sys: 4.12 s, total: 30.9 s
# Wall time: 29 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))

# %% [markdown]
# ## Reflections
#
# Congratulations on finding the lane lines!  As the final step in this project, we would like you to share your thoughts on your lane finding pipeline... specifically, how could you imagine making your algorithm better / more robust?  Where will your current algorithm be likely to fail?
#
# Please add your thoughts below,  and if you're up for making your pipeline more robust, be sure to scroll down and check out the optional challenge video below!

# %% [markdown]
# ## My Reflections
#
# My current algorithm pipeline consists of:
# - gray scale the image
# - Gaussian blur
# - Canny edge detection
# - Masking out area(s) of interest
#     * I masked out FIXED regions for left & right lane lines. (More on this later)
# - Hough transform, on each of the masked regions separately
# - For each region, IF Hough line(s) found:
#     * Use Linear Regression to find a line of best fit
# - Diagnostic plotting capability, and
# - Different modes of output overlays ('Normal' = best fit lane lines, 'Canny', and 'Hough' lines), for diagnostics understanding
#
# I have each of the 3 overlay output videos in my github folder:
# - [white.mp4](./white.mp4)
# - [yellow.mp4](./yellow.mp4)
# - [extra.mp4](./extra.mp4)
#
#
# The **white** & **yellow** videos looked pretty good.
#
# ### Shortcomings
# But the **extra** video has WILD predicted lane lines! Most likely due to **outlier in the Hough transform output lines**. And **linear regression model is susceptible to outliers**.
#
# In order to verify my hypothesis (of poor performance in the Extra video), The Canny edge & Hough transformed overlayed videos showed that shawdows on the road is causing the problem.
# - [white_canny.mp4](white_canny.mp4)
# - [yellow_canny.mp4](yellow_canny.mp4)
# - [extra_canny.mp4](extra_canny.mp4)
# - [white_hough.mp4](white_hough.mp4)
# - [yellow_hough.mp4](yellow_hough.mp4)
# - [extra_hough.mp4](extra_hough.mp4)
#
# Additionally, the **Canny & Hough parameters could be better optimized**. (But I did NOT want to spend too much effort fine-tuning them with the limited dataset of this short learning project, as we **could easily result in an 'over-fitting' / 'high-variance' model situation**.)
#
#
# ### Possible solutions & improvement ideas
# (some I like, from overall systems engineering consideration; some I don't like as much)...
#
# ##### Specify image colors to track the lane lines.
# This would be too easy to 'over-fit' JUST for this problem, and likely won't generalize in real world. I prefer not to use this approach unless there's compelling reason to key off of lane line colors.
#
# ##### Limit frame-to-frame change in predicted lane lines.
# I preferred this solution since in real world driving, lane lines would unlikely to instantaneously change from 1 video frame to another. Thus we could do a time weighted average of predicted lane line from previous frame(s). This will also provide a smoothing effect (over time, `d/dt`). The algorithm would need to save and have knowledge of previous frame information, thus creating a dynamic system with time-varying dependencies. (Which isn't necessarily a bad thing. But would need knowledge and awareness of feedback dynamics & control system to avoid making mistakes. Get an aerospace control systems engineer on your team!!! :smiley:)
#
# ##### Dynamic masking area(s)
# Have the lane line masking area be mutable. This would be more of an improvement capability. Afterall, while we're drivng, (most good drivers) DO LOOK where we are traveling (ie: our velocity vector) _OR_ towards our intended trajectory. Thus dynamic masking could help 'focus' the lane line algorithm. This would help in simple or complex turning situations.
#
#
#
# -Dean Liu
#
# windsurf_dean@yahoo.com
#
# [linkedin.com/in/aerogeekdean](https://www.linkedin.com/in/aerogeekdean)

# %% [markdown]
# ## Submission
#
# If you're satisfied with your video outputs it's time to submit!  Submit this ipython notebook for review.

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
challenge_output = 'extra.mp4'
clip2 = VideoFileClip('challenge.mp4')
challenge_clip = clip2.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False)
# Out:
# [MoviePy] >>>> Building video extra.mp4
# [MoviePy] Writing video extra.mp4
# 100%|██████████| 251/251 [00:23<00:00, 10.46it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: extra.mp4
#
# CPU times: user 27.5 s, sys: 2.93 s, total: 30.4 s
# Wall time: 24.8 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
